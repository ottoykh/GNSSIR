# %%
# !pip install hatanaka
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !chmod +x /content/satref2rinex.py

# %%
# !python ./satref2rinex.py 2025 1 120 hkqt /content/download
# Out:
# Downloaded: /content/download/HKQT00HKG_R_20250010000_01D_30S_MO.crx.gz
# Unzipped: /content/download/HKQT00HKG_R_20250010000_01D_30S_MO.crx
# Converted to .rnx: /content/download/HKQT00HKG_R_20250010000_01D_30S_MO.rnx
# Cleaned up: /content/download/HKQT00HKG_R_20250010000_01D_30S_MO.crx.gz and /content/download/HKQT00HKG_R_20250010000_01D_30S_MO.crx
# Downloaded: /content/download/HKQT00HKG_R_20250020000_01D_30S_MO.crx.gz
# Unzipped: /content/download/HKQT00HKG_R_20250020000_01D_30S_MO.crx
# Converted to .rnx: /content/download/HKQT00HKG_R_20250020000_01D_30S_MO.rnx
# Cleaned up: /content/download/HKQT00HKG_R_20250020000_01D_30S_MO.crx.gz and /content/download/HKQT00HKG_R_20250020000_01D_30S_MO.crx
# Downloaded: /content/download/HKQT00HKG_R_20250030000_01D_30S_MO.crx.gz
# Unzipped: /content/download/HKQT00HKG_R_20250030000_01D_30S_MO.crx
# Converted to .rnx: /content/download/HKQT00HKG_R_20250030000_01D_30S_MO.rnx
# ...

# %%
# !chmod +x /content/rinex_convert.py

# %%
# !chmod +x /content/gfzrnx_2.1.12_lx64

# %%
# !python ./rinex_convert.py /content/download /content/gfzrnx_2.1.12_lx64 1 120 HKQT -output_folder /content/hkqt2025
# Out:
# DATE/TIME           | C | EPOCH / FILE            | SITE | T | MESSAGE
# --------------------+---+-------------------------+------+---+-----------------------------------------------------------...
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | mismatch between header MARKER NAME (HKQT) and file/station name (HKQT00HKG) / using >HKQT<
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | header SYS / PHASE SHIFT: C -> L2I not found
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | header SYS / PHASE SHIFT: C -> L6I not found
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | header SYS / PHASE SHIFT: C -> L7I not found
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | header SYS / PHASE SHIFT: E -> L1X not found
# 2025-05-09 01:49:15 | W | 0000-00-00 00:00:00.000 | HKQT | O | header SYS / PHASE SHIFT: E -> L5X not found
# ...

# %%
# !pip install gnssrefl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 MB 7.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 101.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 9.0 MB/s eta 0:00:00
# ...

# %%
cd /content/hkqt2025
# Out:
# /content/hkqt2025

# %%
# !rinex2snr
# Out:
# gnssrefl version: 3.11.0
#
# usage: rinex2snr [-h] [-snr SNR] [-orb ORB] [-rate low] [-dec DEC]
#                  [-nolook False] [-archive all] [-doy_end DOY_END]
#                  [-year_end YEAR_END] [-overwrite OVERWRITE]
#                  [-translator TRANSLATOR] [-stream STREAM]
#                  [-samplerate SAMPLERATE] [-mk MK] [-weekly WEEKLY]
#                  [-monthly MONTHLY] [-strip STRIP] [-screenstats SCREENSTATS]
#                  [-gzip GZIP] [-par PAR] [-timeout TIMEOUT]
#                  [-extension EXTENSION] [-debug DEBUG]
#                  station year doy
# rinex2snr: error: the following arguments are required: station, year, doy

# %%
# !rinex2snr hkqt 2025 001 -doy_end 120 -nolook T
# Out:
# gnssrefl version: 3.11.0
#
# EXE  not found, so set to current directory
# ORBITS  not found, so set to current directory
# REFL_CODE  not found, so set to current directory
# make output directory for snr files in  2025
# No json file found - but you have requested the code not exit
# Using snr value of  66
# Using default orbit for this time period:  rapid
# Using archive value of  all
# Station  hkqt  has four characters, assume RINEX 2.11 format
# No parallel processing
# SNR file does not already exist. Which means I will try to make it.
# Fortran translation log:  ./logs/hkqt/2025//001_translation.txt
# General log:  ./logs/hkqt/2025//001_translation.txt.gen
# Will first assume station  hkqt  year: 2025  doy: 1 is located here : /content/hkqt2025
#
#
#
#
# SUCCESS: SNR file was created
#  ./2025/snr/hkqt/hkqt0010.25.snr66
# SNR file does not already exist. Which means I will try to make it.
# Fortran translation log:  ./logs/hkqt/2025//002_translation.txt
# ...

# %%
# !gnssir_input hkqt -e1 5.0 -e2 15.0 -h1 0.5 -h2 7.137 -peak2noise 2.8 -ampl 5.0 -refraction True -ediff 2.0 -delTmax 75.0 -azlist2 -45 105
# Out:
# gnssrefl version: 3.11.0
#
# EXE  not found, so set to current directory
# ORBITS  not found, so set to current directory
# REFL_CODE  not found, so set to current directory
# Assume you want to use our database for a priori receiver coordinates.
# Try to download the station database from github for you: https://github.com/kristinemlarson/gnssrefl/raw/master/gnssrefl/station_pos_2024.db
# If you are not online, it will fail.
# If you are able to manually download the file
# it should be stored in the $REFL_CODE/Files directory
# EGM96 file does not exist. We will try to download and store it in  ./Files/
# successful download, EGM file exists
# If you plan to use the NITE refraction model you should choose a better a priori
# Reflector Height. Currently using the default which is not necessarily relevant
# for your site. Hortho value can be used for coastal sites, but not for interior lakes/rivers.
#
# Using default DC removal elevation angle limits, 5 30
# ...

# %%
# !gnssir
# Out:
# gnssrefl version: 3.11.0
#
# usage: gnssir [-h] [-snr SNR] [-plt PLT] [-fr [FR ...]] [-ampl AMPL]
#               [-sat SAT] [-doy_end DOY_END] [-year_end YEAR_END]
#               [-azim1 AZIM1] [-azim2 AZIM2] [-nooverwrite NOOVERWRITE]
#               [-screenstats SCREENSTATS] [-extension EXTENSION]
#               [-compress COMPRESS] [-gzip GZIP] [-delTmax DELTMAX] [-e1 E1]
#               [-e2 E2] [-mmdd MMDD] [-dec DEC] [-savearcs SAVEARCS]
#               [-savearcs_format SAVEARCS_FORMAT] [-par PAR] [-debug DEBUG]
#               station year doy
# gnssir: error: the following arguments are required: station, year, doy

# %%
# !gnssir hkqt 2025 001 -doy_end 110 -savearcs T -screenstats T -fr 1 2 20 5 101 102 201 205
# Out:
# gnssrefl version: 3.11.0
#
# EXE  not found, so set to current directory
# ORBITS  not found, so set to current directory
# REFL_CODE  not found, so set to current directory
# Using these instructions  ./input/hkqt.json
# Using snr file type:  66
# A station specific refraction output file will be written to  ./input/hkqt_refr.txt
# found  ./input/
# The large refraction file should be stored here: ./input/gpt_1wA.pickle
# 1st attempt: not found in  ./input/gpt_1wA.pickle
# 2nd attempt: look in subdirectory of current working directory: gnssrefl/gpt_1wA.pickle
# 3rd attempt try looking here:  /usr/local/lib/python3.11/dist-packages/gnssrefl/gpt_1wA.pickle
# that did not work
# 4th attempt - download from github https://github.com/kristinemlarson/gnssrefl/raw/master/gnssrefl/gpt_1wA.pickle
# station specific refraction file written
# [5, 30]  direct signal elevation angle limits
# ./Files/hkqt  has been created.
# Requested frequencies  [1, 2, 20, 5, 101, 102, 201, 205]
# ...

# %%
# !subdaily
# Out:
# gnssrefl version: 3.11.0
#
# usage: subdaily [-h] [-year_end YEAR_END] [-txtfile_part1 TXTFILE_PART1]
#                 [-txtfile_part2 TXTFILE_PART2] [-csv CSV] [-plt PLT]
#                 [-spline_outlier1 SPLINE_OUTLIER1]
#                 [-spline_outlier2 SPLINE_OUTLIER2] [-knots KNOTS]
#                 [-sigma SIGMA] [-extension EXTENSION] [-rhdot RHDOT]
#                 [-doy1 DOY1] [-doy2 DOY2] [-testing TESTING]
#                 [-ampl [AMPL ...]] [-azim1 AZIM1] [-azim2 AZIM2] [-h1 H1]
#                 [-h2 H2] [-peak2noise PEAK2NOISE] [-kplt KPLT]
#                 [-subdir SUBDIR] [-delta_out DELTA_OUT] [-if_corr IF_CORR]
#                 [-knots_test KNOTS_TEST] [-hires_figs HIRES_FIGS]
#                 [-apply_rhdot APPLY_RHDOT] [-fs FS] [-alt_sigma ALT_SIGMA]
#                 [-gap_min_val GAP_MIN_VAL] [-knots2 KNOTS2]
#                 [-gap_flag GAP_FLAG] [-date1 DATE1] [-date2 DATE2]
#                 station year
# ...

# %%
# !subdaily hkqt 2025 -doy1 001 -doy2 110 -plt T -csv T
# Out:
# gnssrefl version: 3.11.0
#
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<< subdaily >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# EXE  not found, so set to current directory
# ORBITS  not found, so set to current directory
# REFL_CODE  not found, so set to current directory
# Using these instructions  ./input/hkqt.json
# Using this directory for output:  ./Files/hkqt
# You have set the minimum amplitude value using json
# Will pick up and concatenate daily result files
# Reading in the results for year:  2025  and doys  1 : 110
# Will remove daily outliers greater than  2.5  sigma
# Plot to the screen has been set to  True
# >>>>>>>>>>>>>>>>>>>>>>>> readin RH data <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Read in the RH retrievals for  2025  and these days:  1 110
# Number of initial RH retrievals 6816
# 0  points removed for reflector height constraints
# ...
